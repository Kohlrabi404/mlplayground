# %% [markdown]
# <a href="https://colab.research.google.com/github/Kohlrabi404/mlplayground/blob/main/CompenNetTest1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/BingyaoHuang/CompenNet
# !cd CompenNet
# Out:
# Cloning into 'CompenNet'...
# remote: Enumerating objects: 94, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 94 (delta 11), reused 18 (delta 7), pack-reused 63
# Unpacking objects: 100% (94/94), done.

# %%
# !pip install visdom
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 676 kB 5.0 MB/s
# ...
#      |████████████████████████████████| 54 kB 2.9 MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=655250 sha256=9746abf73a6bbb7f7d78f1d86b7941e276c2497942021e640251c8fa051d2bdb
#   Stored in directory: /root/.cache/pip/wheels/2d/d1/9b/cde923274eac9cbb6ff0d8c7c72fe30a3da9095a38fd50bbf1
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=5709 sha256=ebc48da3bedf5401b5cf7981a0bf30b1fb65876cbfc3103002de031d2a1c8fd1
#   Stored in directory: /root/.cache/pip/wheels/ac/5c/3a/a80e1c65880945c71fd833408cd1e9a8cb7e2f8f37620bb75b
# Successfully built visdom torchfile
# ...

# %%
# !npm install -g localtunnel
get_ipython().system_raw('/usr/local/bin/python -m pip install visdom')
get_ipython().system_raw('/usr/local/bin/python -m visdom.server -port 8097 >> visdomlog.txt 2>&1 &')
get_ipython().system_raw('lt --port 8097 >> url.txt 2>&1 &')
import time
time.sleep(5)
# !cat url.txt
import visdom
time.sleep(5)
vis = visdom.Visdom(port='8097')
print(vis)
time.sleep(3)
# !cat visdomlog.txt
# Out:
# /tools/node/bin/lt -> /tools/node/lib/node_modules/localtunnel/bin/lt.js
# + localtunnel@2.0.2
# added 22 packages from 22 contributors in 1.666s
# your url is: https://gentle-worlds-kiss-35-243-183-202.loca.lt
# Setting up a new session...
# ...
# /usr/local/lib/python3.7/dist-packages/visdom/server.py:39: DeprecationWarning: zmq.eventloop.ioloop is deprecated in pyzmq 17. pyzmq now works with default tornado and asyncio eventloops.
#   ioloop.install()  # Needs to happen before any tornado imports!
# INFO:root:Application Started
# INFO:tornado.access:200 POST /env/main (127.0.0.1) 1.58ms
# INFO:tornado.access:101 GET /vis_socket (127.0.0.1) 0.53ms
# INFO:root:Opened visdom socket from ip: 127.0.0.1
# INFO:tornado.access:200 POST /events (127.0.0.1) 0.70ms

# %%
visdom
# Out:
# <module 'visdom' from '/usr/local/lib/python3.7/dist-packages/visdom/__init__.py'>

# %%
# !pip install -r CompenNet/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# ERROR: Could not find a version that satisfies the requirement opencv-python==3.4.4 (from versions: 3.4.0.14, 3.4.2.17, 3.4.3.18, 3.4.4.19, 3.4.5.20, 3.4.6.27, 3.4.7.28, 3.4.8.29, 3.4.9.31, 3.4.9.33, 3.4.10.35, 3.4.10.37, 3.4.11.39, 3.4.11.41, 3.4.11.43, 3.4.11.45, 3.4.13.47, 3.4.14.51, 3.4.14.53, 3.4.15.55, 3.4.16.57, 3.4.16.59, 3.4.17.61, 3.4.17.63, 3.4.18.65, 4.0.0.21, 4.0.1.23, 4.0.1.24, 4.1.0.25, 4.1.1.26, 4.1.2.30, 4.2.0.32, 4.2.0.34, 4.3.0.36, 4.3.0.38, 4.4.0.40, 4.4.0.42, 4.4.0.44, 4.4.0.46, 4.5.1.48, 4.5.2.52, 4.5.2.54, 4.5.3.56, 4.5.4.58, 4.5.4.60, 4.5.5.62, 4.5.5.64, 4.6.0.66)
# ERROR: No matching distribution found for opencv-python==3.4.4

# %%
import cv2
import pandas as pd
import matplotlib.pyplot as plt
print(cv2.__version__)
# Out:
# 4.1.2

# %%
#@markdown <br><center><img src='https://upload.wikimedia.org/wikipedia/commons/thumb/d/da/Google_Drive_logo.png/600px-Google_Drive_logo.png' height="50" alt="Gdrive-logo"/></center>
#@markdown <center><h3>Mount GDrive to /content/drive</h3></center><br>
MODE = "MOUNT" #@param ["MOUNT", "UNMOUNT"]
#Mount your Gdrive! 
from google.colab import drive
drive.mount._DEBUG = False
if MODE == "MOUNT":
  drive.mount('/content/drive', force_remount=True)
elif MODE == "UNMOUNT":
  try:
    drive.flush_and_unmount()
  except ValueError:
    pass
  get_ipython().system_raw("rm -rf /root/.config/Google/DriveFS")
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/CompenNetDataset.zip" -d "/content/CompenNet/data"
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/CompenNet/data/light3/pos3/lavender/cam/warp/train/img_0495.png
#  extracting: /content/CompenNet/data/light3/pos3/lavender/cam/warp/train/img_0496.png
#  extracting: /content/CompenNet/data/light3/pos3/lavender/cam/warp/train/img_0497.png
#  extracting: /content/CompenNet/data/light3/pos3/lavender/cam/warp/train/img_0498.png
#  extracting: /content/CompenNet/data/light3/pos3/lavender/cam/warp/train/img_0499.png
#  extracting: /content/CompenNet/data/light3/pos3/lavender/cam/warp/train/img_0500.png
#    creating: /content/CompenNet/data/light3/pos3/squares/
#    creating: /content/CompenNet/data/light3/pos3/squares/cam/
#    creating: /content/CompenNet/data/light3/pos3/squares/cam/warp/
#    creating: /content/CompenNet/data/light3/pos3/squares/cam/warp/ref/
#  extracting: /content/CompenNet/data/light3/pos3/squares/cam/warp/ref/img_0001.png
# ...

# %%
# !python /content/CompenNet/src/python/main.py
# Out:
# Setting up a new session...
# Train with 1 GPUs!
# Loading data from '/content/CompenNet/data/light2/pos1/curves'
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# -------------------------------------- Training Options -----------------------------------
# data_name: light2_pos1_curves
# model_name: CompenNet
# num_train: 500
# max_iters: 1000
# batch_size: 64
# lr: 0.001
# lr_drop_ratio: 0.2
# lr_drop_rate: 800
# loss: l1+ssim
# l2_reg: 0.0001
# device: cuda
# plot_on: True
# train_plot_rate: 100
# valid_rate: 100
# ...
